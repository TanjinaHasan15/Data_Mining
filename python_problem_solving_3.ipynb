# %% [markdown]
# <a href="https://colab.research.google.com/github/TanjinaHasan15/Data_Mining/blob/main/python_problem_solving_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Take Age, Fare from titanic dataset. Apply max-min, z-score normalization.and compare raw data
# and both normalized data using box-plot and violins plot.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

df = pd.read_csv('titanic.csv')
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data = titanic[['age', 'fare']].dropna()

# %%
minmax = MinMaxScaler()
data_minmax = minmax.fit_transform(data)
data_minmax = pd.DataFrame(data_minmax, columns=['Age_MinMax', 'Fare_MinMax'])

# %%
zscore = StandardScaler()
data_zscore = zscore.fit_transform(data)
data_zscore = pd.DataFrame(data_zscore, columns=['Age_Zscore', 'Fare_Zscore'])

# %%
final = pd.concat([data.reset_index(drop=True), data_minmax, data_zscore], axis=1)

# %%
print(final.head())
# Out:
#     age     fare  Age_MinMax  Fare_MinMax  Age_Zscore  Fare_Zscore
# 0  22.0   7.2500    0.271174     0.014151   -0.530377    -0.518978
# 1  38.0  71.2833    0.472229     0.139136    0.571831     0.691897
# 2  26.0   7.9250    0.321438     0.015469   -0.254825    -0.506214
# 3  35.0  53.1000    0.434531     0.103644    0.365167     0.348049
# 4  35.0   8.0500    0.434531     0.015713    0.365167    -0.503850

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.hist(final['age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Original Age Distribution')

plt.subplot(1,2,2)
plt.hist(final['Age_MinMax'], bins=20, color='orange', edgecolor='black')
plt.title('After Min-Max Normalization (Age)')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.hist(final['fare'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Original Fare Distribution')

plt.subplot(1,2,2)
plt.hist(final['Fare_Zscore'], bins=20, color='salmon', edgecolor='black')
plt.title('After Z-score Normalization (Fare)')

plt.tight_layout()
plt.show()

# %%
df = sns.load_dataset("titanic")
sns.violinplot(x=df["age"])
# Out:
# <Axes: xlabel='age'>

# %%
df = sns.load_dataset("titanic")
sns.violinplot(x=df["fare"])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot(x=titanic["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x=titanic["fare"])
# Out:
# <Axes: xlabel='fare'>
